# %% [markdown]
# <a href="https://colab.research.google.com/github/rdv0777/AB-Test/blob/main/%D0%A3%D1%80%D0%BE%D0%BA_9_Python_%D0%BF%D1%80%D0%B8%D0%BC%D0%B5%D0%BD%D0%B5%D0%BD%D0%B8%D0%B5_%D0%BF%D1%80%D0%BE%D0%B4%D0%B2%D0%B8%D0%BD%D1%83%D1%82%D1%8B%D1%85_%D0%BC%D0%B5%D1%82%D0%BE%D0%B4%D0%BE%D0%B2_Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Урок 9. Python применение продвинутых методов

# %% [markdown]
# Проанализируйте результаты эксперимента и напишите свои рекомендации менеджеру.
#
# Mobile Games AB Testing with Cookie Cats

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/результаты А_B.xlsx')

# %%
df
# Out:
#         userid  version  sum_gamerounds  retention_1  retention_7
# 0          116  gate_30               3            0            0
# 1          337  gate_30              38            1            0
# 2          377  gate_40             165            1            0
# 3          483  gate_40               1            0            0
# 4          488  gate_40             179            1            1
# ...        ...      ...             ...          ...          ...
# 90184  9999441  gate_40              97            1            0
# 90185  9999479  gate_40              30            0            0
# 90186  9999710  gate_30              28            1            0
# 90187  9999768  gate_40              51            1            0
# 90188  9999861  gate_40              16            0            0
#
# [90189 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90189 entries, 0 to 90188
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   userid          90189 non-null  int64
#  1   version         90189 non-null  object
#  2   sum_gamerounds  90189 non-null  int64
#  3   retention_1     90189 non-null  int64
#  4   retention_7     90189 non-null  int64
# dtypes: int64(4), object(1)
# memory usage: 3.4+ MB

# %%
df.describe()
# Out:
#              userid  sum_gamerounds   retention_1   retention_7
# count  9.018900e+04    90189.000000  90189.000000  90189.000000
# mean   4.998412e+06       51.872457      0.445210      0.186065
# std    2.883286e+06      195.050858      0.496992      0.389161
# min    1.160000e+02        0.000000      0.000000      0.000000
# 25%    2.512230e+06        5.000000      0.000000      0.000000
# 50%    4.995815e+06       16.000000      0.000000      0.000000
# 75%    7.496452e+06       51.000000      1.000000      0.000000
# max    9.999861e+06    49854.000000      1.000000      1.000000

# %%
df.nlargest(5,['sum_gamerounds'])
# Out:
#         userid  version  sum_gamerounds  retention_1  retention_7
# 7912    871500  gate_30            2961            1            1
# 29417  3271615  gate_40            2640            1            0
# 43671  4832608  gate_30            2438            1            1
# 48188  5346171  gate_40            2294            1            1
# 46344  5133952  gate_30            2251            1            1

# %% [markdown]
# Удалим выброс

# %%
df = df[df.sum_gamerounds < 3000]
df.describe()
# Out:
#              userid  sum_gamerounds   retention_1   retention_7
# count  9.018800e+04    90188.000000  90188.000000  90188.000000
# mean   4.998397e+06       51.320253      0.445214      0.186056
# std    2.883298e+06      102.682719      0.496992      0.389154
# min    1.160000e+02        0.000000      0.000000      0.000000
# 25%    2.512211e+06        5.000000      0.000000      0.000000
# 50%    4.995804e+06       16.000000      0.000000      0.000000
# 75%    7.496461e+06       51.000000      1.000000      0.000000
# max    9.999861e+06     2961.000000      1.000000      1.000000

# %% [markdown]
# Сравним ворота 30 и ворота 40

# %%
df.gate_30=df[df.version == 'gate_30']
df.gate_40=df[df.version == 'gate_40']
# Out:
# <ipython-input-37-55392fff3bc9>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.gate_30=df[df.version == 'gate_30']
# <ipython-input-37-55392fff3bc9>:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.gate_40=df[df.version == 'gate_40']

# %%
df.gate_30.describe()
# Out:
#              userid  sum_gamerounds   retention_1   retention_7
# count  4.469900e+04    44699.000000  44699.000000  44699.000000
# mean   4.987532e+06       51.342111      0.448198      0.190183
# std    2.881051e+06      102.057598      0.497315      0.392450
# min    1.160000e+02        0.000000      0.000000      0.000000
# 25%    2.505463e+06        5.000000      0.000000      0.000000
# 50%    4.983630e+06       17.000000      0.000000      0.000000
# 75%    7.481522e+06       50.000000      1.000000      0.000000
# max    9.999710e+06     2961.000000      1.000000      1.000000

# %%
df.gate_40.describe()
# Out:
#              userid  sum_gamerounds   retention_1   retention_7
# count  4.548900e+04    45489.000000  45489.000000  45489.000000
# mean   5.009073e+06       51.298776      0.442283      0.182000
# std    2.885496e+06      103.294416      0.496663      0.385849
# min    3.770000e+02        0.000000      0.000000      0.000000
# 25%    2.517171e+06        5.000000      0.000000      0.000000
# 50%    5.007329e+06       16.000000      0.000000      0.000000
# 75%    7.510762e+06       52.000000      1.000000      0.000000
# max    9.999861e+06     2640.000000      1.000000      1.000000

# %% [markdown]
# Из сравнения видно, что у ворота 30 немного выше среднее по удержанию 1 и 7

# %%
df.version.value_counts()
# Out:
# gate_40    45489
# gate_30    44699
# Name: version, dtype: int64

# %% [markdown]
# Число версий примерно одинаковы.

# %% [markdown]
# Проверка на нормальность

# %%
from scipy.stats import kstest
print(kstest(df['sum_gamerounds'][df.version == 'gate_30'], 'norm'))
print(kstest(df['sum_gamerounds'][df.version == 'gate_40'], 'norm'))
# Out:
# KstestResult(statistic=0.8724153079945488, pvalue=0.0, statistic_location=2, statistic_sign=-1)
# KstestResult(statistic=0.8707186187388001, pvalue=0.0, statistic_location=2, statistic_sign=-1)

# %% [markdown]
# Распределение не нормальное. Используем тест Манна-Уитни.

# %%
from scipy.stats import mannwhitneyu

# %%
mannwhitneyu(df[df.version == 'gate_30'].sum_gamerounds,
             df[df.version == 'gate_40'].sum_gamerounds)
# Out:
# MannwhitneyuResult(statistic=1024285761.5, pvalue=0.05089155279145376)

# %% [markdown]
# ###Вывод

# %% [markdown]
# Т. к. рvalue находится в пограничном состоянии, немного большее 0,05, то рекомендуется версия gate_30, т. к. среднее удержание 1 и 7 больше именно в этой версии.
